# %%
# 1.a
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 4*y
deq2 = diff(y,t) == x + y
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

show(solutions)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
# 1.b
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == 2*x - y
deq2 = diff(y,t) == x + 2*y
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

show(solutions)
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
# 1.c
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x,t) == x - y + z
deq2 = diff(y,t) == x + y - z
deq3 = diff(z,t) == -y + 2*z

syst = [deq1, deq2, deq3]

C1, C2, C3 = var('C1, C2, C3')

solutions = desolve_system(syst, [x,y,z], [0, C1, C2, C3])

show(solutions)
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
# 1.d
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == 5*x(t)+3*y(t)+1
deq2 = diff(y,t) == -6*x(t)-4*y(t)+e^(-t)
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

show(solutions)
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
# 1.e
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 3*y + cos(t)
deq2 = diff(y,t) == x - y + 2*t
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

show(solutions)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
# 1.f
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x,t) == x - 2*y -2*z + e^(-t)
deq2 = diff(y,t) == -2*x + y + 2*z
deq3 = diff(z,t) == 2*x - y - 3*z + e^(-t)

syst = [deq1, deq2, deq3]

C1, C2, C3 = var('C1, C2, C3')

solutions = desolve_system(syst, [x,y,z], [0, C1, C2, C3])

show(solutions)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
# 2.a
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 4*y
deq2 = diff(y,t) == x + y
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

sol_x(t,C1,C2)=solutions[0].rhs()
sol_y(t,C1,C2)=solutions[1].rhs()

show(sol_x)
show(sol_y)

g1 = plot(sol_x(t,1,2),t,-4,4, ymax=100, color='red')
g2 = plot(sol_y(t,1,2),t,-4,4, ymax=100)
show(g1+g2)
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)
# Graphics object consisting of 2 graphics primitives

# %%
# 2.b
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x - y + t - 1
deq2 = diff(y,t) == -2*x + 4*y + cos(t)
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

sol_x(t,C1,C2)=solutions[0].rhs()
sol_y(t,C1,C2)=solutions[1].rhs()

show(sol_x)
show(sol_y)

g1 = plot(sol_x(t,0,1),t,-4,4, ymax=100, ymin=-100, color='red')
g2 = plot(sol_y(t,0,1),t,-4,4, ymax=100, ymin=-100)
show(g1+g2)
# Out:
# (t, C1, C2) |--> -1/221*(sqrt(17)*(39*C1 + 26*C2 + 144)*sinh(1/2*sqrt(17)*t) - 17*(13*C1 + 33)*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2
# (t, C1, C2) |--> -1/442*(sqrt(17)*(104*C1 - 78*C2 + 129)*sinh(1/2*sqrt(17)*t) - 17*(26*C2 + 45)*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2
# Graphics object consisting of 2 graphics primitives

# %%
# 2.c
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x + 2*y + e^(-t)
deq2 = diff(y,t) == -2*x + y + 1
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

sol_x(t,C1,C2)=solutions[0].rhs()
sol_y(t,C1,C2)=solutions[1].rhs()

show(sol_x)
show(sol_y)

g1 = plot(sol_x(t,0,1),t,-2,6, ymax=150, ymin=-200, color='red')
g2 = plot(sol_y(t,0,1),t,-2,6, ymax=150, ymin=-200)
show(g1+g2)
# Out:
# (t, C1, C2) |--> 1/20*((20*C1 - 3)*cos(2*t) + (20*C2 + 9)*sin(2*t))*e^t - 1/4*e^(-t) + 2/5
# (t, C1, C2) |--> 1/20*((20*C2 + 9)*cos(2*t) - (20*C1 - 3)*sin(2*t))*e^t - 1/4*e^(-t) - 1/5
# Graphics object consisting of 2 graphics primitives

# %%
# 2.d
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x,t) == x + 2*y + e^(-t)
deq2 = diff(y,t) == -2*x + y + 1
deq3 = diff(z,t) == -2*x+3*y+6*z+3
syst = [deq1, deq2, deq3]

C1, C2, C3 = var('C1, C2, C3')

solutions = desolve_system(syst, [x,y,z], [0, C1, C2, C3])

sol_x(t,C1,C2,C3)=solutions[0].rhs()
sol_y(t,C1,C2,C3)=solutions[1].rhs()
sol_z(t,C1,C2,C3)=solutions[2].rhs()

show(sol_x)
show(sol_y)
show(sol_z)

g1 = plot(sol_x(t,50,-30,26),t,-4,5, ymax=2050, ymin=-800, color='red')
g2 = plot(sol_y(t,50,-30,26),t,-4,5, ymax=2050, ymin=-800)
g3 = plot(sol_z(t,50,-30,26),t,-4,5, ymax=2050, ymin=-800,color='green')
show(g1+g2+g3)
# Out:
# (t, C1, C2, C3) |--> 1/20*((20*C1 - 3)*cos(2*t) + (20*C2 + 9)*sin(2*t))*e^t - 1/4*e^(-t) + 2/5
# (t, C1, C2, C3) |--> 1/20*((20*C2 + 9)*cos(2*t) - (20*C1 - 3)*sin(2*t))*e^t - 1/4*e^(-t) - 1/5
# (t, C1, C2, C3) |--> -1/609*(336*C1 - 231*C2 - 609*C3 - 295)*e^(6*t) + 1/580*((320*C1 - 220*C2 - 147)*cos(2*t) + (220*C1 + 320*C2 + 111)*sin(2*t))*e^t + 1/28*e^(-t) - 4/15
# Graphics object consisting of 3 graphics primitives

# %%
#3.a

reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x+y
deq2 = diff(y,t) == -2*x + 4*y
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

sol_x(t,C1,C2)=solutions[0].rhs()
sol_y(t,C1,C2)=solutions[1].rhs()

show("Sol 1:")
s_x1(t) = sol_x(t,3,0)
s_y1(t) = sol_y(t,3,0)
show("x(t)=",s_x1)
show("y(t)=",s_y1)

show("Sol 2:")
s_x2(t) = sol_x(t,0,3)
s_y2(t) = sol_y(t,0,3)
show("x(t)=",s_x2)
show("y(t)=",s_y2)

show("Sol 3:")
s_x3(t) = sol_x(t,-3,0)
s_y3(t) = sol_y(t,-3,0)
show("x(t)=",s_x3)
show("y(t)=",s_y3)

show("Sol 4:")
s_x4(t) = sol_x(t,0,-3)
s_y4(t) = sol_y(t,0,-3)
show("x(t)=",s_x4)
show("y(t)=",s_y4)
# Out:
# 'Sol 1:'
# 'x(t)=' t |--> -3*e^(3*t) + 6*e^(2*t)
# 'y(t)=' t |--> -6*e^(3*t) + 6*e^(2*t)
# 'Sol 2:'
# 'x(t)=' t |--> 3*e^(3*t) - 3*e^(2*t)
# 'y(t)=' t |--> 6*e^(3*t) - 3*e^(2*t)
# 'Sol 3:'
# 'x(t)=' t |--> 3*e^(3*t) - 6*e^(2*t)
# 'y(t)=' t |--> 6*e^(3*t) - 6*e^(2*t)
# 'Sol 4:'
# 'x(t)=' t |--> -3*e^(3*t) + 3*e^(2*t)
# 'y(t)=' t |--> -6*e^(3*t) + 3*e^(2*t)

# %%
# 3b
show("x1(t) ->",limit(s_x1(t),t=Infinity),"  y1(t) ->",limit(s_y1(t),t=Infinity))

show("x2(t) ->",limit(s_x2(t),t=Infinity),"  y2(t) ->",limit(s_y2(t),t=Infinity))

show("x3(t) ->",limit(s_x3(t),t=Infinity),"  y3(t) ->",limit(s_y3(t),t=Infinity))

show("x4(t) ->",limit(s_x4(t),t=Infinity),"  y4(t) ->",limit(s_y4(t),t=Infinity))
# Out:
# 'x1(t) ->' -Infinity '  y1(t) ->' -Infinity
# 'x2(t) ->' +Infinity '  y2(t) ->' +Infinity
# 'x3(t) ->' +Infinity '  y3(t) ->' +Infinity
# 'x4(t) ->' -Infinity '  y4(t) ->' -Infinity

# %%
# 3c

u = var('u')
v = var('v')
f1(u,v) = u+v
f2(u,v) = -2*u + 4*v

plot_vector_field([f1(u,v),f2(u,v)], [u, -10, 10], [v, -10, 10], aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# 4a

reset()

t = var('t')
x = function('x')(t)
y = function('y')(t)

deq1 = diff(x(t),t) == y
deq2 = diff(y(t),t) == -x-2*y

C1, C2 = var('C1, C2')

sols = desolve_system([deq1,deq2],[x,y], [0, C1, C2])
show(sols)
# Out:
# [x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t),
#  y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)]

# %%
# 4b

sol_x = sols[0].rhs()
sol_y = sols[1].rhs()

show("x(t) --> ",limit(sol_x(t),t=Infinity))
show("y(t) --> ",limit(sol_y(t),t=Infinity))
# Out:
# 'x(t) --> ' 0
# 'y(t) --> ' 0

# %%
# 4c

u = var('u')
v = var('v')
f1(u,v) = v
f2(u,v) = -u-2*v

plot_vector_field([f1(u,v),f2(u,v)], [u, -10, 10], [v, -5, 5],color="red")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5a

reset()

u = var('u')
v = var('v')
f1(u,v) = 2*u+v
f2(u,v) = u+2*v

plot_vector_field([f1(u,v),f2(u,v)], [u, -20, 20], [v, -20, 20], aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5b

reset()

u = var('u')
v = var('v')
f1(u,v) = -u-v
f2(u,v) = u-v

plot_vector_field([f1(u,v),f2(u,v)], [u, -20, 20], [v, -20, 20], aspect_ratio=1,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5c

reset()

u = var('u')
v = var('v')
f1(u,v) = v
f2(u,v) = -u

plot_vector_field([f1(u,v),f2(u,v)], [u, -10, 10], [v, -10, 10], aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5d

reset()

u = var('u')
v = var('v')
f1(u,v) = -2*u
f2(u,v) = -4*u-2*v

plot_vector_field([f1(u,v),f2(u,v)], [u, -5, 5], [v, -5, 5], aspect_ratio=1, color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#5e

reset()

u = var('u')
v = var('v')
f1(u,v) = u-4*v
f2(u,v) = 5*u-3*v

t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x,t) == x-4*y
deq2 = diff(y,t) == 5*x-3*y
syst = [deq1, deq2]

C1, C2 = var('C1, C2')

solutions = desolve_system(syst, [x,y], [0, C1, C2])

sol_x(t,C1,C2)=solutions[0].rhs()
sol_y(t,C1,C2)=solutions[1].rhs()

g1 = parametric_plot((sol_x(t,3,3), sol_y(t,3,3)), (t, 0, 5))

g2 = plot_vector_field([f1(u,v),f2(u,v)], [u, -10, 10], [v, -5, 5], color='red')

show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#5f

reset()

u = var('u')
v = var('v')
f1(u,v) = 3*u-v
f2(u,v) = v

plot_vector_field([f1(u,v),f2(u,v)], [u, -100, 100], [v, -100, 100], aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive
