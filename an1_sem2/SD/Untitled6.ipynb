# %%
# 1 a
reset()

s = var('s')
f = function('f')(s)
f(s) = s^2 - 2*s

eqp = solve(f(s)==0, s)
show(eqp)

x1 = eqp[0].rhs()
x2 = eqp[1].rhs()

d1 = diff(f,s)(x1)
d2 = diff(f,s)(x2)
if d1>0:
    show(x1, " local asimptotic stabil")
else:
    show(x1, " instabil")
    
if d2>0:
    show(x2, " local asimptotic stabil")
else:
    show(x2, " instabil")

t = var('t')
    
sf = plot_slope_field(f(s), (t,-10,10), (s, -3, 3), 
                 headaxislength=3, headlength=1, color='black')

x = function('x')(t)
deq = diff(x,t) == f(x)

g1 = desolve_rk4(deq, x, [0, 2], step=0.5, end_points=[-10,10], output='plot', color='red')
g2 = desolve_rk4(deq, x, [0, 1.5], step=0.5, end_points=[-10,10], output='plot', color='red')
g3 = desolve_rk4(deq, x, [0, 0.7], step=0.5, end_points=[-10,10], output='plot', color='red')
g4 = desolve_rk4(deq, x, [0, 0], step=0.5, end_points=[-10,10], output='plot', color='red')

g = sf + g1+g2+g3+g4
g.show(ymin=-3, ymax=3)
# Out:
# [s == 0, s == 2]
# 0 ' instabil'
# 2 ' local asimptotic stabil'
# Graphics object consisting of 5 graphics primitives

# %%
# 2a

reset()
A = matrix([[2, 1], [1, 2]])

A.eigenvalues()

x, y, t = var('x, y, t')
f1(x,y) = 2*x + y
f2(x,y) = x + 2*y

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,1,-1], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l1 = list_plot(XY, plotjoined=True, color='blue')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,2,3], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l2 = list_plot(XY, plotjoined=True, color='green')

pl=g+l1+l2
pl.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
# 2b

reset()
A = matrix([[-3, 4], [-2, 3]])

A.eigenvalues()

x, y, t = var('x, y, t')
f1(x,y) = -3*x + 4*y
f2(x,y) = -2*x + 3*y

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,1,-1], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l1 = list_plot(XY, plotjoined=True, color='blue')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,2,3], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l2 = list_plot(XY, plotjoined=True, color='green')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0, 3,2], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l3 = list_plot(XY, plotjoined=True, color='orange')

pl=g+l1+l2+l3
pl.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>
#      13 g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-Integer(5),Integer(5)], [y,-Integer(5),Integer(5)], color='red')
#      14
# ---> 15 P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[Integer(0),Integer(1),-Integer(1)], ivar=t, end_points=[-Integer(3),Integer(3)])
#      16 XY = [[j,k] for i,j,k in P]
#      17 l1 = list_plot(XY, plotjoined=True, color='blue')
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/calculus/desolvers.py in desolve_system_rk4(des, vars, ics, ivar, end_points, step)
#    1501     varstr = "[" + ",".join(varss) + "]"
#    1502     x0=ics[0]
# -> 1503     icss = [ics[i]._maxima_().str() for i in range(1,len(ics))]
#    1504     icstr = "[" + ",".join(icss) + "]"
#    1505     step=abs(step)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/calculus/desolvers.py in <listcomp>(.0)
#    1501     varstr = "[" + ",".join(varss) + "]"
#    1502     x0=ics[0]
# -> 1503     icss = [ics[i]._maxima_().str() for i in range(1,len(ics))]
#    1504     icstr = "[" + ",".join(icss) + "]"
#    1505     step=abs(step)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._maxima_ (build/cythonized/sage/structure/sage_object.c:8215)()
#     789             import sage.interfaces.maxima
#     790             G = sage.interfaces.maxima.maxima
# --> 791         return self._interface_(G)
#     792
#     793     def _maxima_init_(self):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/sage_object.pyx in sage.structure.sage_object.SageObject._interface_ (build/cythonized/sage/structure/sage_object.c:5759)()
#     690             except Exception:
#     691                 raise NotImplementedError("coercion of object %s to %s not implemented:\n%s\n%s" % (repr(self), I))
# --> 692         X = I(s)
#     693         if c:
#     694             try:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/interface.py in __call__(self, x, name)
#     293
#     294         if isinstance(x, str):
# --> 295             return cls(self, x, name=name)
#     296         try:
#     297             # Special methods do not and should not have an option to
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in __init__(self, parent, value, is_name, name)
#    1168             True
#    1169         """
# -> 1170         ExpectElement.__init__(self, parent, value, is_name=False, name=None)
#    1171
#    1172     def display2d(self, onscreen=True):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in __init__(self, parent, value, is_name, name)
#    1466         else:
#    1467             try:
# -> 1468                 self._name = parent._create(value, name=name)
#    1469             # Convert ValueError and RuntimeError to TypeError for
#    1470             # coercion to work properly.
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/interface.py in _create(self, value, name)
#     498     def _create(self, value, name=None):
#     499         name = self._next_var_name() if name is None else name
# --> 500         self.set(name, value)
#     501         return name
#     502
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in set(self, var, value)
#    1013             self._batch(cmd, batchload=True)
#    1014         else:
# -> 1015             self._eval_line(cmd)
#    1016             #self._sendline(cmd)
#    1017             #self._expect_expr()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in _eval_line(self, line, allow_use_file, wait_for_prompt, reformat, error_check, restart_if_needed)
#     793             return repr(a)
#     794         else:
# --> 795             self._sendline(line)
#     796
#     797         line_echo = self._readline()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in _sendline(self, string)
#     655             '9'
#     656         """
# --> 657         self._sendstr(string)
#     658         os.write(self._expect.child_fd, os.linesep.encode('ascii'))
#     659
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _sendstr(self, string)
#    1247         """
#    1248         if self._expect is None:
# -> 1249             self._start()
#    1250         try:
#    1251             os.write(self._expect.child_fd, str_to_bytes(string))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in _start(self)
#     620
#     621         """
# --> 622         Expect._start(self)
#     623         self._sendline(r":lisp (defun tex-derivative (x l r) (tex (if $derivabbrev (tex-dabbrev x) (tex-d x '\\partial)) l r lop rop ))")
#     624
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _start(self, alt_message, block_during_init)
#     498                         # Work around https://bugs.python.org/issue1652
#     499                         preexec_fn=lambda: signal.signal(signal.SIGPIPE, signal.SIG_DFL),
# --> 500                         quit_string=self._quit_string())
#     501             except (ExceptionPexpect, pexpect.EOF) as e:
#     502                 # Change pexpect errors to RuntimeError
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn.__init__ (build/cythonized/sage/interfaces/sagespawn.c:1984)()
#      63         kwds.setdefault("maxread", 4194304)
#      64
# ---> 65         with ContainChildren(silent=True):
#      66             spawn.__init__(self, *args, **kwds)
#      67
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn.__init__ (build/cythonized/sage/interfaces/sagespawn.c:1938)()
#      64
#      65         with ContainChildren(silent=True):
# ---> 66             spawn.__init__(self, *args, **kwds)
#      67
#      68         self.delaybeforesend = None
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     203             self.name = '<pexpect factory incomplete>'
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#     207
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     302
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 304                                      cwd=self.cwd, **kwargs)
#     305
#     306         self.pid = self.ptyproc.pid
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn._spawnpty (build/cythonized/sage/interfaces/sagespawn.c:2175)()
#      80             SagePtyProcess.spawn(...)
#      81         """
# ---> 82         ptyproc = SagePtyProcess.spawn(args, **kwds)
#      83         ptyproc.quit_string = self.quit_string
#      84         return ptyproc
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions)
#     218
#     219         if use_native_pty_fork:
# --> 220             pid, fd = pty.fork()
#     221         else:
#     222             # Use internal fork_pty, for Solaris
#
# /usr/lib/python3.7/pty.py in fork()
#      95
#      96     master_fd, slave_fd = openpty()
# ---> 97     pid = os.fork()
#      98     if pid == CHILD:
#      99         # Establish a new session.
#
# BlockingIOError: [Errno 11] Resource temporarily unavailable

# %%
# 3b

reset()

x,y,t = var('x,y,t')

f1(x,y) = -2*x+y+2
f2(x,y) = x*y


EquilP = solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(EquilP)

J=jacobian((f1(x,y),f2(x,y)),(x,y))

for sol in EquilP:
    xs=sol[0].rhs()
    ys=sol[1].rhs()
    ev = J(x=xs, y=ys).eigenvalues()    
    l1=ev[0]
    l2=ev[1]
    if l1 in RR:
        if l1>0 and l2>0:
            show(xs,", ",ys," instabil de tip nod")
        elif l2>0:
            show(xs,", ",ys," instabil de tip sa")
        else:
            show(xs,", ",ys," stabil...")
    else:
        show(xs,", ",ys," local asimptotic stabil tip focus")
        
    show(ev)
    

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,1,-1], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l1 = list_plot(XY, plotjoined=True, color='blue')

pl=g+l1
pl.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# [[x == 1, y == 0], [x == 0, y == -2]]
# 1 ', ' 0 ' instabil de tip sa'
# [-2, 1]
# 0 ', ' -2 ' local asimptotic stabil tip focus'
# [-I - 1, I - 1]
# Graphics object consisting of 2 graphics primitives

# %%
# 4

reset()

x,y,t = var('x,y,t')

f1(x,y) = 2*x - 1.2 *x*y
f2(x,y) = -y+0.9*x*y


EquilP = solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(EquilP)

J=jacobian((f1(x,y),f2(x,y)),(x,y))

for sol in EquilP:
    xs=sol[0].rhs()
    ys=sol[1].rhs()
    ev = J(x=xs, y=ys).eigenvalues()    
    l1=ev[0]
    l2=ev[1]
    if l1 in RR:
        if l1>0 and l2>0:
            show(xs,", ",ys," instabil de tip nod")
        elif l2>0:
            show(xs,", ",ys," instabil de tip sa")
        else:
            show(xs,", ",ys," stabil...")
    else:
        show(xs,", ",ys," local asimptotic stabil tip focus")
        
    show(ev)
    

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,0.5,2], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l1 = list_plot(XY, plotjoined=True, color='blue')

pl=g+l1
pl.show(xmin=0, xmax=5, ymin=0, ymax=5)
# Out:
# [[x == 0, y == 0], [x == (10/9), y == (5/3)]]
# 0 ', ' 0 ' instabil de tip sa'
# [-1, 2]
# 10/9 ', ' 5/3 ' local asimptotic stabil tip focus'
# [-I*sqrt(2), I*sqrt(2)]
# Graphics object consisting of 2 graphics primitives

# %%
# 3c

reset()

x,y,t = var('x,y,t')

f1(x,y) = -x*x-y*y
f2(x,y) = x*y-1


EquilP = solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(EquilP)

J=jacobian((f1(x,y),f2(x,y)),(x,y))

for sol in EquilP:
    xs=sol[0].rhs()
    ys=sol[1].rhs()
    if not (xs in RR):
        continue
    ev = J(x=xs, y=ys).eigenvalues()    
    l1=ev[0]
    l2=ev[1]
    if l1 in RR:
        if l1>0 and l2>0:
            show(xs,", ",ys," instabil de tip nod")
        elif l2>0:
            show(xs,", ",ys," instabil de tip sa")
        else:
            show(xs,", ",ys," stabil...")
    else:
        show(xs,", ",ys," local asimptotic stabil tip focus")
        
    show(ev)
    

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-5,5], color='red')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,1,-1], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l1 = list_plot(XY, plotjoined=True, color='blue')

pl=g+l1
pl.show(xmin=-5, xmax=5, ymin=-5, ymax=5)
# Out:
# [[x == sqrt(-I), y == I*sqrt(-I)], [x == -(-1)^(1/4), y == (-1)^(3/4)], [x == (-1)^(1/4), y == -(-1)^(3/4)]]
# Graphics object consisting of 2 graphics primitives

# %%
# 3a

reset()

x,y,t = var('x,y,t')

f1(x,y) = y
f2(x,y) = x*(1-x*x)+y


EquilP = solve([f1(x,y)==0, f2(x,y)==0],x,y)
show(EquilP)

J=jacobian((f1(x,y),f2(x,y)),(x,y))

for sol in EquilP:
    xs=sol[0].rhs()
    ys=sol[1].rhs()
    if not (xs in RR):
        continue
    ev = J(x=xs, y=ys).eigenvalues()    
    l1=ev[0]
    l2=ev[1]
    if l1 in RR:
        if l1>0 and l2>0:
            show(xs,", ",ys," instabil de tip nod")
        elif l2>0:
            show(xs,", ",ys," instabil de tip sa")
        else:
            show(xs,", ",ys," stabil...")
    else:
        show(xs,", ",ys," local asimptotic stabil tip focus")
        
    show(ev)
    

n=sqrt(f1(x,y)^2+f2(x,y)^2)
g=plot_vector_field([f1(x,y)/n, f2(x,y)/n], [x,-5,5], [y,-10,10], color='red')

P = desolve_system_rk4([f1(x,y), f2(x,y)], [x,y], ics=[0,1,-1], ivar=t, end_points=[-3,3])
XY = [[j,k] for i,j,k in P]
l1 = list_plot(XY, plotjoined=True, color='blue')

pl=g+l1
pl.show(xmin=-5, xmax=5, ymin=-10, ymax=10)
# Out:
# [[x == -1, y == 0], [x == 1, y == 0], [x == 0, y == 0]]
# -1 ', ' 0 ' local asimptotic stabil tip focus'
# [-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]
# 1 ', ' 0 ' local asimptotic stabil tip focus'
# [-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]
# 0 ', ' 0 ' instabil de tip sa'
# [-1/2*sqrt(5) + 1/2, 1/2*sqrt(5) + 1/2]
# Graphics object consisting of 2 graphics primitives

# %%
# 1 b
reset()

s = var('s')
f = function('f')(s)
f(s) = s*(s-1)*(s-2)

eqp = solve(f(s)==0, s)
show(eqp)

for sol in eqp:
    xi = sol.rhs()
    di = diff(f,s)(xi)
    if di>0:
        show(xi, " local asimptotic stabil")
    else:
        show(xi, " instabil")

t = var('t')
    
sf = plot_slope_field(f(s), (t,-10,10), (s, -3, 3),                  
                 headaxislength=3, headlength=1, color='black')

x = function('x')(t)
deq = diff(x,t) == f(x)

g1 = desolve_rk4(deq, x, [0, 2], step=0.5, end_points=[-10,10], output='plot', color='red')
g2 = desolve_rk4(deq, x, [0, 1.5], step=0.5, end_points=[-10,10], output='plot', color='red')
g3 = desolve_rk4(deq, x, [0, 0.7], step=0.5, end_points=[-10,10], output='plot', color='red')
g4 = desolve_rk4(deq, x, [0, 0], step=0.5, end_points=[-10,10], output='plot', color='red')

g = sf + g1+g2+g3+g4
g.show(ymin=-3, ymax=3)
# Out:
# [s == 0, s == 1, s == 2]
# 0 ' local asimptotic stabil'
# 1 ' instabil'
# 2 ' local asimptotic stabil'
# ---------------------------------------------------------------------------
# BlockingIOError                           Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/all_cmdline.py in <module>
#      25 deq = diff(x,t) == f(x)
#      26
# ---> 27 g1 = desolve_rk4(deq, x, [Integer(0), Integer(2)], step=RealNumber('0.5'), end_points=[-Integer(10),Integer(10)], output='plot', color='red')
#      28 g2 = desolve_rk4(deq, x, [Integer(0), RealNumber('1.5')], step=RealNumber('0.5'), end_points=[-Integer(10),Integer(10)], output='plot', color='red')
#      29 g3 = desolve_rk4(deq, x, [Integer(0), RealNumber('0.7')], step=RealNumber('0.5'), end_points=[-Integer(10),Integer(10)], output='plot', color='red')
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/calculus/desolvers.py in desolve_rk4(de, dvar, ics, ivar, end_points, step, output, **kwds)
#    1376     step=abs(step)
#    1377     de0=de._maxima_()
# -> 1378     maxima("load('dynamics)")
#    1379     lower_bound,upper_bound=desolve_rk4_determine_bounds(ics,end_points)
#    1380     sol_1, sol_2 = [],[]
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/interface.py in __call__(self, x, name)
#     293
#     294         if isinstance(x, str):
# --> 295             return cls(self, x, name=name)
#     296         try:
#     297             # Special methods do not and should not have an option to
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in __init__(self, parent, value, is_name, name)
#    1168             True
#    1169         """
# -> 1170         ExpectElement.__init__(self, parent, value, is_name=False, name=None)
#    1171
#    1172     def display2d(self, onscreen=True):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in __init__(self, parent, value, is_name, name)
#    1466         else:
#    1467             try:
# -> 1468                 self._name = parent._create(value, name=name)
#    1469             # Convert ValueError and RuntimeError to TypeError for
#    1470             # coercion to work properly.
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/interface.py in _create(self, value, name)
#     498     def _create(self, value, name=None):
#     499         name = self._next_var_name() if name is None else name
# --> 500         self.set(name, value)
#     501         return name
#     502
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in set(self, var, value)
#    1013             self._batch(cmd, batchload=True)
#    1014         else:
# -> 1015             self._eval_line(cmd)
#    1016             #self._sendline(cmd)
#    1017             #self._expect_expr()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in _eval_line(self, line, allow_use_file, wait_for_prompt, reformat, error_check, restart_if_needed)
#     793             return repr(a)
#     794         else:
# --> 795             self._sendline(line)
#     796
#     797         line_echo = self._readline()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in _sendline(self, string)
#     655             '9'
#     656         """
# --> 657         self._sendstr(string)
#     658         os.write(self._expect.child_fd, os.linesep.encode('ascii'))
#     659
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _sendstr(self, string)
#    1247         """
#    1248         if self._expect is None:
# -> 1249             self._start()
#    1250         try:
#    1251             os.write(self._expect.child_fd, str_to_bytes(string))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima.py in _start(self)
#     620
#     621         """
# --> 622         Expect._start(self)
#     623         self._sendline(r":lisp (defun tex-derivative (x l r) (tex (if $derivabbrev (tex-dabbrev x) (tex-d x '\\partial)) l r lop rop ))")
#     624
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/expect.py in _start(self, alt_message, block_during_init)
#     498                         # Work around https://bugs.python.org/issue1652
#     499                         preexec_fn=lambda: signal.signal(signal.SIGPIPE, signal.SIG_DFL),
# --> 500                         quit_string=self._quit_string())
#     501             except (ExceptionPexpect, pexpect.EOF) as e:
#     502                 # Change pexpect errors to RuntimeError
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn.__init__ (build/cythonized/sage/interfaces/sagespawn.c:1984)()
#      63         kwds.setdefault("maxread", 4194304)
#      64
# ---> 65         with ContainChildren(silent=True):
#      66             spawn.__init__(self, *args, **kwds)
#      67
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn.__init__ (build/cythonized/sage/interfaces/sagespawn.c:1938)()
#      64
#      65         with ContainChildren(silent=True):
# ---> 66             spawn.__init__(self, *args, **kwds)
#      67
#      68         self.delaybeforesend = None
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     203             self.name = '<pexpect factory incomplete>'
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#     207
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     302
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 304                                      cwd=self.cwd, **kwargs)
#     305
#     306         self.pid = self.ptyproc.pid
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/sagespawn.pyx in sage.interfaces.sagespawn.SageSpawn._spawnpty (build/cythonized/sage/interfaces/sagespawn.c:2175)()
#      80             SagePtyProcess.spawn(...)
#      81         """
# ---> 82         ptyproc = SagePtyProcess.spawn(args, **kwds)
#      83         ptyproc.quit_string = self.quit_string
#      84         return ptyproc
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions)
#     218
#     219         if use_native_pty_fork:
# --> 220             pid, fd = pty.fork()
#     221         else:
#     222             # Use internal fork_pty, for Solaris
#
# /usr/lib/python3.7/pty.py in fork()
#      95
#      96     master_fd, slave_fd = openpty()
# ---> 97     pid = os.fork()
#      98     if pid == CHILD:
#      99         # Establish a new session.
#
# BlockingIOError: [Errno 11] Resource temporarily unavailable

# %%
# 1 c
reset()

s = var('s')
f = function('f')(s)
f(s) = sin(s)

eqp = solve(f(s)==0, s, to_poly_solve='force')
show(eqp)

k=var('k')
xk=k*pi

assume(k, 'integer')
ans = diff(f,s)(xk)
a = ans.trig_simplify()
show(a)
eqp=[-1,1]

for xi in eqp:    
    di = diff(f,s)(xi)
    if di>0:
        show(xi, " local asimptotic stabil")
    else:
        show(xi, " instabil")

t = var('t')
    
sf = plot_slope_field(f(s), (t,-10,10), (s, -3, 3),                  
                 headaxislength=3, headlength=1, color='black')

x = function('x')(t)
deq = diff(x,t) == f(x)

g1 = desolve_rk4(deq, x, [0, 1], step=0.5, end_points=[-10,10], output='plot', color='red')
g2 = desolve_rk4(deq, x, [0, -0.7], step=0.5, end_points=[-10,10], output='plot', color='red')
g3 = desolve_rk4(deq, x, [0, -1], step=0.5, end_points=[-10,10], output='plot', color='red')
g4 = desolve_rk4(deq, x, [0, 0.3], step=0.5, end_points=[-10,10], output='plot', color='red')

g = sf + g1+g2+g3+g4
g.show(ymin=-3, ymax=3)


forget()
# Out:
# [s == pi*z2736]
# (-1)^k
# -1 ' local asimptotic stabil'
# 1 ' local asimptotic stabil'
# Graphics object consisting of 5 graphics primitives

# %%
# 2 a
reset()
